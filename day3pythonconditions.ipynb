# %% [markdown]
# - if else
# -- if condition is true, it prints true
# if num > 0:

# %%
# -*- coding: utf-8 -*-
# @Time    : 2023/10/24 11:00


def check_number():
    num = int(input("Enter a number: "))

    if num > 0:
        print("Positive number")
    elif num == 0:
        print("Zero")
    else:
        print('negative number')    
    
    
print(check_number())
# Out:
# negative number
# None

# %%
def checck_number():
    num = int(input('enter the number: '))
    if num > 0:
        print('positive number')
    elif num == 0:
        print('zero')
    else:
        print('negative')
            
            
print(checck_number())

what if i want to keep it in a function and call it from another file?
how can we call it from another file ?
# Out:
# negative
# None

# %%
give another example using short hand approach

# %%
number = 4

print('positive number') if number > 0 else print('negative')
# Out:
# positive number

# %% [markdown]
# -- short hand approach:

# %% [markdown]
# Exercises: Level 1
# Get user input using input(“Enter your age: ”). If user is 18 or older, give feedback: You are old enough to drive. If below 18 give feedback to wait for the missing amount of years. Output:
#
# Enter your age: 30
# You are old enough to learn to drive.
# Output:
# Enter your age: 15
# You need 3 more years to learn to drive.
# Compare the values of my_age and your_age using if … else. Who is older (me or you)? Use input(“Enter your age: ”) to get the age as input. You can use a nested condition to print 'year' for 1 year difference in age, 'years' for bigger differences, and a custom text if my_age = your_age. Output:
#
# Enter your age: 30
# You are 5 years older than me.
#    Get two numbers from the user using input prompt. If a is greater than b return a is greater than b, if a is less b return a is smaller than b, else a is equal to b. Output:
#
# Enter number one: 4
# Enter number two: 3
# 4 is greater than 3

# %%
age = int(input('enter your age: '))
if age >= 18:
    print('you are old enough to drive')
else: 
    print(f'you need to wait for {18-age} years')
# Out:
# you need to wait for 7 years

# %%
age = int(input('enter your age: '))
if age >= 18:
    print('you are old enough to drive')
else:
    print(f'you are still young, come back in  {18-age} before trying again')
# Out:
# you are still young, come back in  7 before trying again

# %%
age = int(input('enter your age: '))
years_left = 20 -age
print(f'you should have started driving {years_left} years ago') if age >= 18 else print(f'you are still young, come back in {years_left} before trying again')
# Out:
# you should have started driving -30 years ago

# %%
#nested loops
for i in range(5):
    for j in range(5):
        print(j*i)



\'/'\
   
   \\
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 1
# 2
# 3
# 4
# 0
# 2
# 4
# 6
# 8
# 0
# 3
# 6
# 9
# 12
# 0
# 4
# 8
# 12
# 16

# %% [markdown]
# -- nested conditions
# one thing is placed within another.
# nested condition are conditions within another condition
# syntax
# if

# %% [markdown]
# z
