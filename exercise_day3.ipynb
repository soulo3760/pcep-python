# %% [markdown]
# Exercises: Level 1
# Get user input using input(“Enter your age: ”). If user is 18 or older, give feedback: You are old enough to drive. If below 18 give feedback to wait for the missing amount of years. Output:
#
# Enter your age: 30
# You are old enough to learn to drive.
# Output:
# Enter your age: 15
# You need 3 more years to learn to drive.

# %%
age = int(input('enter your age: '))
gap = 18 - age
print(f' at {age} you are old enough to learn driving ') if age>=18 else print(f' you need {gap} more years to learn driving')
# Out:
#  you need 7 more years to learn driving

# %% [markdown]
# Compare the values of my_age and your_age using if … else. Who is older (me or you)? Use input(“Enter your age: ”) to get the age as input. You can use a nested condition to print 'year' for 1 year difference in age, 'years' for bigger differences, and a custom text if my_age = your_age. Output:
#
# Enter your age: 30
# You are 5 years older than me.

# %%
your_age = int(input('Enter your age:' ))
my_age = 29
gap = your_age - my_age
if  my_age < your_age:
    if gap < 1:
        print(f' it seems your age is {your_age} which is greater than mine which is {my_age}, You are {gap} year older than me.')
    else:
        print(f' it seems your age is {your_age} which is greater than mine which is {my_age}, You are {gap} years older than me.')
elif my_age == your_age:
    print(f'it seems your age {your_age} is the same as mine {my_age}, what a concidennce maybe we share the same birth month too ')
else:   print(f' it seems your age is {your_age} is less than mine which is {my_age} by {gap} years.')
# Out:
#  it seems your age is 31 which is greater than mine which is 29, You are 2 years older than me.

# %% [markdown]
# Get two numbers from the user using input prompt. If a is greater than b return a is greater than b, if a is less b return a is smaller than b, else a is equal to b. Output:
#
# Enter number one: 4
# Enter number two: 3
# 4 is greater than 3

# %%
num_a = int(input('enter the number one '))
num_b =  int(input('enter the number one '))

if num_a > num_b:
    print(f'{num_a} is greater than {num_b}')
else:  print(f'{num_b} is greater than {num_a}')
# Out:
# 4 is greater than 1

# %% [markdown]
# Exercises: Level 2
# Write a code which gives grade to students according to their scores:
#
# 80-100, A
# 70-89, B
# 60-69, C
# 50-59, D
# 0-49, F

# %%
for score in range(0, 101):
    if 80 <= score <= 100:
        grade = 'A'
    elif 70 <= score <= 79:
        grade = 'B'
    elif 60 <= score <= 69:
        grade = 'C'
    elif 50 <= score <= 59:
        grade = 'D'
    elif 0 <= score <= 49:
        grade = 'F'
    print(f'The grade for the score {score} is: {grade}')

# %%
score = int(input('Enter your score: '))
def determine_grade(score):
        if 80 <= score <= 100:
            return 'A'
        elif 70 <= score <= 79:
            return 'B'
        elif 60 <= score <= 69:
            return 'C'
        elif 50 <= score <= 59:
            return 'D'
        elif 40 <= score <= 49:
            return 'E'
        elif 0 <= score <= 39:
            return 'F'
        else:
            return 'Invalid score. Please enter a score between 0 and 100.'


grade = determine_grade(score)
print(f'The grade for the score {score} is: {grade}')
# Out:
# The grade for the score 43 is: E

# %%
def bmi_calc():
    bmi = weight / (height ** 2)
    print(f'your bmi score is {bmi}')
    if bmi > 30:
        print('you are obese')
    elif 27 < bmi <= 30:
        print(f'you are overweight at {bmi} score')
    elif 25 < bmi <= 27:
        print(f'you are okay weight at {bmi} score')
    else:
        print(f'you are underweight at {bmi} score')
    return bmi

score = bmi_calc()
print(f'based on your {weight} kgs and {height} cm height, your BMI score shows you are {score}')
# Out:
# your bmi score is 0.003271604938271605
# you are underwight at at {bmi} score
#  based on your 106 kgs and 180 cm height our bmi score shows u rNone

# %%
weight = int(input('kindly weight your self'))
height = int(input('what is your height'))
bmi = weight/(height**2)
def bmi_calc(*weightss):
    bmi = weight/(height**2)
    print(f'your bmi score is {bmi}')
    if bmi > 30:
        print('you are obese')
    elif 27 < bmi < 30:
        print(f'you are overweight at {bmi} score')
    elif 25 < bmi < 27:
        print('you are okay weight at at {bmi} score')
    else: print('you are underwight at at {bmi} score')
    
    
score = bmi_calc()
print (f' based on your {weight} kgs and {height} cm height our bmi score shows u r{score}')
