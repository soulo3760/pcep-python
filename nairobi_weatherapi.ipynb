# %%
import requests
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
import pandas as pd
# Load environment variables from .env file



load_dotenv()
api_key = os.getenv("api_key")

url = f"http://api.openweathermap.org/data/2.5/weather?q=Kisumu&appid={api_key}"
response = requests.get(url)    
response.json()

# Check if the request was successful (status code 200)
if response.status_code == 200:
    weather_data = response.json()
    print(weather_data)
# Extract relevant data from the response
city_name = weather_data['name']
temperature = weather_data['main']['temp']
humidity = weather_data['main']['humidity']
description = weather_data['weather'][0]['description']
# Print the extracted data
print(f"The city name is {city_name} and has a humidity of {humidity}% and a temperature of {temperature}°C with a weather description of {description}.")

# Create a DataFrame from the extracted data
data = {
    'city_name': [city_name],
    'temperature': [temperature],
    'humidity': [humidity],
    'description': [description]
}
    
df = pd.DataFrame(data)
# Print the DataFrame
print(df)
# Save the DataFrame to postgreSQL database
df.head()
# Out:
# {'coord': {'lon': 34.7617, 'lat': -0.1022}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 296.04, 'feels_like': 296.55, 'temp_min': 296.04, 'temp_max': 296.04, 'pressure': 1015, 'humidity': 83, 'sea_level': 1015, 'grnd_level': 887}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 300}, 'rain': {'1h': 1.3}, 'clouds': {'all': 40}, 'dt': 1746552936, 'sys': {'type': 1, 'id': 2547, 'country': 'KE', 'sunrise': 1746502452, 'sunset': 1746546053}, 'timezone': 10800, 'id': 191245, 'name': 'Kisumu', 'cod': 200}
# The city name is Kisumu and has a humidity of 83% and a temperature of 296.04°C with a weather description of moderate rain.
#   city_name  temperature  humidity    description
# 0    Kisumu       296.04        83  moderate rain
#   city_name  temperature  humidity    description
# 0    Kisumu       296.04        83  moderate rain

# %%
    
# Connect to PostgreSQL database using environment variables
# Connect to PostgreSQL database
    
# Get database connection details from environment variables
user=os.getenv('user')
password=os.getenv('password')
host=os.getenv('host')
port=os.getenv('port')
database=os.getenv('database')

engine = create_engine(f"postgresql://{user}:{password}@{host}:{port}/{database}")

df.to_sql('weather_data', engine,schemas='public', if_exists='replace', index=False)
print("Data inserted successfully")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 14
#       9 database=os.getenv('database')
#      12 engine = create_engine(f"postgresql://{user}:{password}@{host}:{port}/{database}")
# ---> 14 df.to_sql('weather_data', engine,schemas='public', if_exists='replace', index=False)
#      15 print("Data inserted successfully")
#
# File c:\Users\HP\Desktop\coding luxsd\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
pip list 
pip freeze > requirements.txt
# Out:
# Package                 Version
# ----------------------- -----------
# asttokens               3.0.0
# certifi                 2025.4.26
# charset-normalizer      3.4.2
# colorama                0.4.6
# comm                    0.2.2
# debugpy                 1.8.14
# decorator               5.2.1
# executing               2.2.0
# greenlet                3.2.1
# idna                    3.10
# ipykernel               6.29.5
# ipython                 9.1.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# jupyter_client          8.6.3
# jupyter_core            5.7.2
# matplotlib-inline       0.1.7
# nest-asyncio            1.6.0
# numpy                   2.2.5
# packaging               24.2
# pandas                  2.2.3
# parso                   0.8.4
# pip                     25.1.1
# platformdirs            4.3.7
# prompt_toolkit          3.0.50
# psutil                  7.0.0
# psycopg2-binary         2.9.10
# pure_eval               0.2.3
# ...

# %%
df.to_csv()
df.to_sql

import requests
import pandas as pd
url = "https://jsonplaceholder.typicode.com/posts"
response = requests.get(url)

data = response.json()

struct_data = pd.DataFrame(data)
print(data)
print(struct_data)
# Save the DataFrame to a CSV file
struct_data.to_csv('data.csv', index=False)
# push the DataFrame to a PostgreSQL database
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv
# Load environment variables from .env file
load_dotenv()
# Get database connection details from environment variables    
user=os.getenv('user')
password=os.getenv('password')
host=os.getenv('host')
port=os.getenv('port')
database=os.getenv('database')
engine = create_engine(f"postgresql://{user}:{password}@{host}:{port}/{database}")
