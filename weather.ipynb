# %%
import requests
#api_key= "0739cf807ce62a6cb1d15c6f696ae8f6"
url = f"http://api.openweathermap.org/data/2.5/weather?q=London&appid={api_key}"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    print(f"Weather in {data['name']}: {data['weather'][0]['description']}")
    print(f"Temperature: {data['main']['temp']}K")
# Out:
# Weather in London: few clouds
# Temperature: 283.55K

# %%
import requests

#api_key= "0739cf807ce62a6cb1d15c6f696ae8f6"
url = "https://api.openweathermap.org/data/2.5/weather"
response = requests.get(url)
response.json()
response = requests.get(url, params={"q": "London", "appid": api_key})
response.json()
data = response.json()
print(f"Humidity: {data['main']['humidity']}%")
print(f"the city of {data['name']} has a temperature of {data['main']['temp']}K")
print(data)
# Out:
# Humidity: 60%
# the city of London has a temperature of 283.55K
# {'coord': {'lon': -0.1257, 'lat': 51.5085}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 283.55, 'feels_like': 282.21, 'temp_min': 283.55, 'temp_max': 283.55, 'pressure': 1025, 'humidity': 60, 'sea_level': 1025, 'grnd_level': 1021}, 'visibility': 10000, 'wind': {'speed': 4.4, 'deg': 35, 'gust': 6.13}, 'clouds': {'all': 11}, 'dt': 1746522315, 'sys': {'country': 'GB', 'sunrise': 1746505383, 'sunset': 1746559867}, 'timezone': 3600, 'id': 2643743, 'name': 'London', 'cod': 200}

# %%
url = f"http://api.openweathermap.org/data/2.5/weather?q=Nairobi&appid={api_key}"
response = requests.get(url)
data = response.json()
print(data)
print(f"The city of {data['name']} is located at a latitude of {data['coord']['lat']}, and a longitude of {data['coord']['lon']}")
print(f"It is a {data['weather'][0]['description']} city, with humidity of {data['main']['humidity']}% and temperature of {data['main']['temp']}K")
# Out:
# {'coord': {'lon': 36.8167, 'lat': -1.2833}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 295.63, 'feels_like': 295.5, 'temp_min': 295.63, 'temp_max': 295.63, 'pressure': 1016, 'humidity': 60, 'sea_level': 1016, 'grnd_level': 840}, 'visibility': 10000, 'wind': {'speed': 2.54, 'deg': 125, 'gust': 2.96}, 'rain': {'1h': 0.25}, 'clouds': {'all': 96}, 'dt': 1746522221, 'sys': {'country': 'KE', 'sunrise': 1746502043, 'sunset': 1746545476}, 'timezone': 10800, 'id': 184745, 'name': 'Nairobi', 'cod': 200}
# The city of Nairobi is located at a latitude of -1.2833, and a longitude of 36.8167
# It is a light rain city, with humidity of 60% and temperature of 295.63K
